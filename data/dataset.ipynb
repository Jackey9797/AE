# %%
file_name = r"feature/part-00000-5ae21edc-d5a1-44db-bce8-2e655479a231-c000.csv" 

import pandas as pd 

df = pd.read_csv(file_name)
df
# Out:
#        user  day  week_id  role_id  business_unit_id  functional_unit_id  \
# 0         1   53        7       22                 0                   5
# 1         1  109       15       22                 0                   5
# 2         1  140       20       22                 0                   5
# 3         1  173       24       22                 0                   5
# 4         1  178       25       22                 0                   5
# ...     ...  ...      ...      ...               ...                 ...
# 24751  1000  398       57       30                 0                   2
# 24752  1000  404       57       30                 0                   2
# 24753  1000  436       62       30                 0                   2
# 24754  1000  442       63       30                 0                   2
# 24755  1000  496       71       30                 0                   2
#
#        department_id  team_id  is_it_admin   O  ...  \
# ...
